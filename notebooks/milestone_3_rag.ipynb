# %% [markdown]
# # Milestone 3: Context Augmentation with RAG Pipelines
# Retrieving external knowledge via TF-IDF Vector Database to augment question prompts.

# %%
import sys
sys.path.append('../scripts')
from vector_db import VectorDB

vdb = VectorDB()
print('Vector DB initialized for RAG context retrieval!')
