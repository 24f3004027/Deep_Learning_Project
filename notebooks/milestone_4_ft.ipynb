# %% [markdown]
# # Milestone 4: MCQ Task Formulation & LoRA Fine-Tuning
# Setting up multiple-choice sequence classification loop and PEFT rank parameters.

# %%
from peft import LoraConfig, get_peft_model
print('PEFT package ready for LoRA fine-tuning!')
